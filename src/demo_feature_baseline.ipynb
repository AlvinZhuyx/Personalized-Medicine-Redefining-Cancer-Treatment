# %%
import os
import re
import tqdm
import string
import pandas as pd
import numpy as np
import util
from sklearn.decomposition import TruncatedSVD
#from data_preprocessing import *
import word_embedding_load as wel
import baseline_classification as bc
import matplotlib.pyplot as plt
# Out:
# C:\Users\zhuya\Anaconda3\envs\tensorflow\lib\site-packages\gensim\utils.py:862: UserWarning: detected Windows; aliasing chunkize to chunkize_serial
#   warnings.warn("detected Windows; aliasing chunkize to chunkize_serial")

# %%
import feature_selection_evaluation as fse
modelName = ['docEmbeddings_win2_load_all.d2v', 'docEmbeddings_win30_load_all.d2v']

# %%
fse.runTextModelEval(modelName)
# Out:
# Successfully loaded the textmodel from ../model/doc2vec/docEmbeddings_win2_load_all.d2v
# Results for TextModel: docEmbeddings_win2_load_all.d2v
# Accuracy: 0.6191 ± 0.0213
# NMI: 0.3965 ± 0.0294
# Log_loss: 6.5382 ± 0.4916
# Normalized confusion matrix
# [[ 0.63444109  0.02265861  0.00906344  0.21752266  0.06646526  0.03323263
#    0.01661631  0.          0.        ]
#  [ 0.08032129  0.48594378  0.0060241   0.04016064  0.01606426  0.02610442
#    0.34538153  0.          0.        ]
#  [ 0.10416667  0.05208333  0.375       0.17708333  0.04166667  0.          0.25
#    0.          0.        ]
#  [ 0.21038615  0.02796272  0.01065246  0.69107856  0.02929427  0.00532623
#    0.0252996   0.          0.        ]
#  [ 0.2659176   0.06741573  0.03370787  0.12359551  0.36329588  0.03745318
#    0.10861423  0.          0.        ]
#  [ 0.14814815  0.08754209  0.01010101  0.05387205  0.04040404  0.5993266
#    0.06060606  0.          0.        ]
#  [ 0.04933586  0.16223909  0.03036053  0.01518027  0.01518027  0.00664137
#    0.71726755  0.          0.00379507]
#  [ 0.23809524  0.28571429  0.          0.04761905  0.          0.
#    0.0952381   0.14285714  0.19047619]
#  [ 0.02325581  0.09302326  0.          0.04651163  0.02325581  0.
#    0.04651163  0.          0.76744186]]
# Successfully loaded the textmodel from ../model/doc2vec/docEmbeddings_win30_load_all.d2v
# Results for TextModel: docEmbeddings_win30_load_all.d2v
# Accuracy: 0.5853 ± 0.0194
# NMI: 0.3571 ± 0.0231
# Log_loss: 7.1425 ± 0.5590
# Normalized confusion matrix
# [[ 0.58912387  0.0407855   0.01057402  0.22205438  0.0694864   0.04229607
#    0.02416918  0.          0.00151057]
#  [ 0.12048193  0.47590361  0.0060241   0.03815261  0.01204819  0.02409639
#    0.32128514  0.          0.00200803]
#  [ 0.125       0.03125     0.375       0.1875      0.03125     0.          0.25
#    0.          0.        ]
#  [ 0.22636485  0.02796272  0.01464714  0.66977364  0.03062583  0.00932091
#    0.01997337  0.          0.00133156]
#  [ 0.28089888  0.06741573  0.02996255  0.09737828  0.35580524  0.05243446
#    0.11610487  0.          0.        ]
#  [ 0.16835017  0.06734007  0.01010101  0.05723906  0.05050505  0.58585859
#    0.05723906  0.003367    0.        ]
#  [ 0.08444023  0.16982922  0.03320683  0.02087287  0.0227704   0.00948767
#    0.65559772  0.          0.00379507]
#  [ 0.0952381   0.42857143  0.          0.          0.          0.04761905
#    0.14285714  0.14285714  0.14285714]
#  [ 0.11627907  0.06976744  0.          0.04651163  0.02325581  0.
#    0.04651163  0.          0.69767442]]
