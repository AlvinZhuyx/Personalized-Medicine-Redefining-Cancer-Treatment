# %%
import os
import re
import tqdm
import string
import pandas as pd
import numpy as np
import util
from sklearn.decomposition import TruncatedSVD
#from data_preprocessing import *
import word_embedding_load as wel
import baseline_classification as bc
import matplotlib.pyplot as plt
import feature_selection_evaluation as fse

# %%
modelName = ['docEmbeddings_5_load.d2v', 'docEmbeddings_30_load_all.d2v']

# %%
fse.runTextModelEval(modelName)
# Out:
# Successfully loaded the textmodel from ../model/doc2vec/docEmbeddings_5_load.d2v
# Results for TextModel: docEmbeddings_5_load.d2v
# Accuracy: 0.5674 ± 0.0305
# NMI: 0.3233 ± 0.0331
# Log_loss: 8.2758 ± 0.6999
# Normalized confusion matrix
# [[ 0.54380665  0.04984894  0.00755287  0.2326284   0.05891239  0.03927492
#    0.06495468  0.          0.00302115]
#  [ 0.12048193  0.45783133  0.00401606  0.04216867  0.01606426  0.02409639
#    0.33333333  0.          0.00200803]
#  [ 0.09375     0.05208333  0.35416667  0.19791667  0.04166667  0.
#    0.26041667  0.          0.        ]
#  [ 0.20372836  0.0505992   0.01464714  0.64447403  0.03595206  0.00798935
#    0.03861518  0.          0.00399467]
#  [ 0.27340824  0.07116105  0.03370787  0.11235955  0.33333333  0.04494382
#    0.13108614  0.          0.        ]
#  [ 0.15488215  0.0976431   0.01346801  0.04713805  0.05050505  0.54882155
#    0.08754209  0.          0.        ]
#  [ 0.07020873  0.17362429  0.02751423  0.0313093   0.0142315   0.00759013
#    0.66982922  0.          0.0056926 ]
#  [ 0.23809524  0.14285714  0.          0.          0.          0.04761905
#    0.19047619  0.14285714  0.23809524]
#  [ 0.11627907  0.04651163  0.          0.11627907  0.          0.
#    0.09302326  0.02325581  0.60465116]]
# Successfully loaded the textmodel from ../model/doc2vec/docEmbeddings_30_load_all.d2v
# Results for TextModel: docEmbeddings_30_load_all.d2v
# Accuracy: 0.6110 ± 0.0214
# NMI: 0.3925 ± 0.0274
# Log_loss: 6.5794 ± 0.5453
# Normalized confusion matrix
# [[ 0.60725076  0.02719033  0.01057402  0.23111782  0.06646526  0.03172205
#    0.02416918  0.00151057  0.        ]
#  [ 0.07028112  0.49799197  0.01204819  0.03413655  0.01807229  0.02008032
#    0.34738956  0.          0.        ]
#  [ 0.09375     0.03125     0.38541667  0.19791667  0.04166667  0.          0.25
#    0.          0.        ]
#  [ 0.23169108  0.02130493  0.01065246  0.67376831  0.03195739  0.00532623
#    0.02396804  0.          0.00133156]
#  [ 0.2659176   0.05617978  0.02996255  0.12734082  0.35955056  0.0411985
#    0.11985019  0.          0.        ]
#  [ 0.14478114  0.1010101   0.00673401  0.05050505  0.03367003  0.58922559
#    0.07070707  0.003367    0.        ]
#  [ 0.04933586  0.16034156  0.03225806  0.01802657  0.01612903  0.00664137
#    0.71347249  0.          0.00379507]
#  [ 0.14285714  0.23809524  0.          0.04761905  0.          0.
#    0.14285714  0.19047619  0.23809524]
#  [ 0.09302326  0.02325581  0.          0.02325581  0.02325581  0.
#    0.04651163  0.          0.79069767]]

# %%
# TODO:
'''
1, Different length of representation (SVD, for each part?), call api and get results
2, 

'''
